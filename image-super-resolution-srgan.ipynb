# %% [markdown]
# # Import Libraries

# %%
/kaggle/input/fastmri/training_gt_aug.pickle

# %%
# for plotting 
import matplotlib.pyplot as plt
import cv2
# for vectors manipultion 
import numpy as np

# for walking in the dir
import os

# tensorflow  libraries to preprocess the data
import tensorflow_addons as tfa
from tensorflow.keras.layers import RandomCrop
import tensorflow_transform as tft

# for building the network
import tensorflow as tf
from tensorflow.keras.applications import VGG19
from tensorflow.keras import Model
from keras.layers import Conv2D
from keras import Input
from keras.layers import PReLU,LeakyReLU
from keras.layers import UpSampling2D
from keras.layers import BatchNormalization
from keras.layers import add,Dense, Flatten
from keras import activations

from tqdm import tqdm
from keras.models import load_model
import keras
import keras.utils
from keras import utils as np_utils
import keras.backend as K
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_17/1868245843.py in <module>
#      35
#      36
# ---> 37 fastmri_path = kagglehub.dataset_download('yeafly/fastmri')
#
# NameError: name 'kagglehub' is not defined

# %%
ImgDataset=[]
i=0
for dirname, _, filenames in os.walk('../input/image-dataset/train2014/'):    
    for filename in filenames:
        if filename.endswith(".jpg"):
            ImgDataset.append(os.path.join(dirname, filename))
            i+=1 
print(i)
# Out:
# 82783

# %% [markdown]
# # Data generator and the preporcessing

# %%
randomcrop1 = RandomCrop(96,96)
min_maxScale = tf.keras.layers.Rescaling(scale= 1./255)
range_Scaling = tf.keras.layers.Rescaling(scale= 1./127.5,offset=-1)
def prepare_Image_tf(imgPath): 
    # Read the image
    '''img = tf.io.read_file(imgPath)
    img = tf.image.decode_jpeg(img, channels=0)'''
    img = tf.keras.utils.load_img(
    imgPath,
    grayscale=False,
    color_mode='rgb',
    )
    
    HR = randomcrop1(img)
    
    # constructing the LR images 
    LR= tfa.image.gaussian_filter2d(image= HR,
        filter_shape = (3, 3),
        sigma = 1.0,
        padding = 'REFLECT')
    
    LR = tf.image.resize(LR, [24, 24])
    LR = min_maxScale(LR)
    
    # Normalizing the HR images 
    HR = range_Scaling(HR)
    return LR,HR

# %%
def get_batch(getImg= prepare_Image_tf,dataset=ImgDataset,batchSize=16): 
    HRbatch=[]
    LRbatch=[]
    for counter,path in enumerate(dataset):
        LR,HR=getImg(path)
        HRbatch.append(HR)
        LRbatch.append(LR)
        if (counter+1)%batchSize == 0: 
            yield tf.stack(LRbatch),tf.stack(HRbatch)
            HRbatch=[]
            LRbatch=[]

# %% [markdown]
# # Visualizing a sample from the dataset

# %%
dataloader = get_batch()
LRB,HRB = next(dataloader)

plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
plt.imshow(LRB[7])
plt.subplot(1,2,2)
plt.imshow(HRB[7])

# %% [markdown]
# # Building the model

# %% [markdown]
# ## Discriminative Model

# %%
def repeatedBlock(INPUT,C,s):
    Block= Conv2D(C,(3,3),padding='same',strides=(s,s))(INPUT)
    BN= BatchNormalization(axis = -1)(Block)
    op= LeakyReLU(alpha=0.2)(BN)
    return op

def descriminator(INPUT):
    FILTERS=64
    Block = Conv2D(64,(3,3),padding='same')(INPUT)
    Block = LeakyReLU(alpha=0.2)(Block)
    layer= repeatedBlock(Block,FILTERS,2)
    for i in range(3):
        FILTERS*=2
        layer= repeatedBlock(layer,FILTERS,1)
        layer= repeatedBlock(layer,FILTERS,2)

    flattened= Flatten()(layer)
    layer2= Dense(1024)(flattened)
    layer3= LeakyReLU(alpha=0.2)(layer2)
    op= Dense(1,activation=activations.sigmoid)(layer3)
    return Model(inputs=INPUT, outputs=op)

# %% [markdown]
# ## Generative model

# %%
def upScaleBlock(INPUT):
    #use_bias=False
    Block=Conv2D(256,(3,3),padding='same',use_bias=False)(INPUT)
    Block2=UpSampling2D(size=2)(Block)
    #Block2= PixelShuffler()(Block)
    Block3=PReLU(shared_axes=[1, 2])(Block2)
    # the SHARED AXIS is used instead of the shufflerthat exists in pytorcha nd the real model
    # am not quite sure BUT if this is not ture then i'd have to implement or get a module for it 
  
    return Block3

# %%
def resBlock(INPUT):
    #use_bias=False
    Block=Conv2D(64,(3,3),padding='same',use_bias=False)(INPUT)
    #axis=-1
    BN=BatchNormalization(axis=-1)(Block)
    ACTIV=PReLU(shared_axes=[1, 2])(BN)

    Block2=Conv2D(64,(3,3),padding='same')(ACTIV)
    #axis=-1

    BN2=BatchNormalization(axis=-1)(Block2)

    # the SHARED AXIS is used instead of the shufflerthat exists in pytorcha nd the real model
    return add([INPUT,BN2])

# %%
def GAN_generator(INPUT):
    Block=Conv2D(64,(9,9),padding='same')(INPUT)
    layer=PReLU(shared_axes=[1, 2])(Block)
  
    #change
    layer2= resBlock(layer)
    for i in range(15):
        layer2= resBlock(layer2)
  
    Block2=Conv2D(64,(3,3),padding='same')(layer2)
    BN3=BatchNormalization(momentum=0.85)(Block2)
    layer3= add([layer,layer2])

    layer4= upScaleBlock(layer3)
    layer4= upScaleBlock(layer4)

    op=Conv2D(3,(9,9),padding='same')(layer4)
    return Model(inputs=INPUT,outputs=op)

# %% [markdown]
# ### VGG19

# %%
def create_vgg19(imgShape): 
    vgg= VGG19(include_top=False,
               weights="imagenet",
               input_shape=imgShape)
    model =Model(inputs=vgg.inputs,outputs=vgg.layers[20].output)
    model.trainable=False
    return model

vgg19=create_vgg19((96,96,3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 4s 0us/step
# 80150528/80134624 [==============================] - 4s 0us/step

# %% [markdown]
# ## linking GAN networks

# %%
def Link_GAN(generator, discriminator, vgg, lr, hr):
    generated_image = generator(lr)
    generated_features = vgg(generated_image)
    
    discriminator.trainable = False
    validity = discriminator(generated_image)
    
    return Model(inputs=[lr, hr], outputs=[validity, generated_features])

# %% [markdown]
# # Let'sTrain the model

# %%
LR = Input(shape=(24,24,3))
HR = Input(shape=(96,96,3))
## Generator
Generator = GAN_generator(LR)
Generator.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 24, 24, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 24, 24, 64)   15616       input_2[0][0]
# __________________________________________________________________________________________________
# p_re_lu (PReLU)                 (None, 24, 24, 64)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 24, 24, 64)   36864       p_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 24, 24, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# p_re_lu_1 (PReLU)               (None, 24, 24, 64)   64          batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 24, 24, 64)   36928       p_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 24, 24, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 24, 24, 64)   0           p_re_lu[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 24, 24, 64)   36864       add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 24, 24, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# p_re_lu_2 (PReLU)               (None, 24, 24, 64)   64          batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 24, 24, 64)   36928       p_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 24, 24, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 24, 24, 64)   0           add[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 24, 24, 64)   36864       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 24, 24, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# p_re_lu_3 (PReLU)               (None, 24, 24, 64)   64          batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 24, 24, 64)   36928       p_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 24, 24, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 24, 24, 64)   0           add_1[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 24, 24, 64)   36864       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 24, 24, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# p_re_lu_4 (PReLU)               (None, 24, 24, 64)   64          batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 24, 24, 64)   36928       p_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 24, 24, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 24, 24, 64)   0           add_2[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 24, 24, 64)   36864       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 24, 24, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# p_re_lu_5 (PReLU)               (None, 24, 24, 64)   64          batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 24, 24, 64)   36928       p_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 24, 24, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 24, 24, 64)   0           add_3[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 24, 24, 64)   36864       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 24, 24, 64)   256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# p_re_lu_6 (PReLU)               (None, 24, 24, 64)   64          batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 24, 24, 64)   36928       p_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 24, 24, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 24, 24, 64)   0           add_4[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 24, 24, 64)   36864       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 24, 24, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# p_re_lu_7 (PReLU)               (None, 24, 24, 64)   64          batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 24, 24, 64)   36928       p_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 24, 24, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 24, 24, 64)   0           add_5[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 24, 24, 64)   36864       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 24, 24, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# p_re_lu_8 (PReLU)               (None, 24, 24, 64)   64          batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 24, 24, 64)   36928       p_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 24, 24, 64)   256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 24, 24, 64)   0           add_6[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 24, 24, 64)   36864       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 24, 24, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# p_re_lu_9 (PReLU)               (None, 24, 24, 64)   64          batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 24, 24, 64)   36928       p_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 24, 24, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 24, 24, 64)   0           add_7[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 24, 24, 64)   36864       add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 24, 24, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# p_re_lu_10 (PReLU)              (None, 24, 24, 64)   64          batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 24, 24, 64)   36928       p_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 24, 24, 64)   256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 24, 24, 64)   0           add_8[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 24, 24, 64)   36864       add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 24, 24, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# p_re_lu_11 (PReLU)              (None, 24, 24, 64)   64          batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 24, 24, 64)   36928       p_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 24, 24, 64)   256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 24, 24, 64)   0           add_9[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 24, 24, 64)   36864       add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 24, 24, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# p_re_lu_12 (PReLU)              (None, 24, 24, 64)   64          batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 24, 24, 64)   36928       p_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 24, 24, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 24, 24, 64)   0           add_10[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 24, 24, 64)   36864       add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 24, 24, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# p_re_lu_13 (PReLU)              (None, 24, 24, 64)   64          batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 24, 24, 64)   36928       p_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 24, 24, 64)   256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 24, 24, 64)   0           add_11[0][0]
#                                                                  batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 24, 24, 64)   36864       add_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 24, 24, 64)   256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# p_re_lu_14 (PReLU)              (None, 24, 24, 64)   64          batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 24, 24, 64)   36928       p_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 24, 24, 64)   256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 24, 24, 64)   0           add_12[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 24, 24, 64)   36864       add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 24, 24, 64)   256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# p_re_lu_15 (PReLU)              (None, 24, 24, 64)   64          batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 24, 24, 64)   36928       p_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 24, 24, 64)   256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 24, 24, 64)   0           add_13[0][0]
#                                                                  batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 24, 24, 64)   36864       add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 24, 24, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# p_re_lu_16 (PReLU)              (None, 24, 24, 64)   64          batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 24, 24, 64)   36928       p_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 24, 24, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 24, 24, 64)   0           add_14[0][0]
#                                                                  batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 24, 24, 64)   0           p_re_lu[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 24, 24, 256)  147456      add_16[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 48, 48, 256)  0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# p_re_lu_17 (PReLU)              (None, 48, 48, 256)  256         up_sampling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 48, 48, 256)  589824      p_re_lu_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 96, 96, 256)  0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# p_re_lu_18 (PReLU)              (None, 96, 96, 256)  256         up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 96, 96, 3)    62211       p_re_lu_18[0][0]
# ==================================================================================================
# Total params: 2,005,571
# Trainable params: 2,001,475
# Non-trainable params: 4,096
# __________________________________________________________________________________________________

# %%
## Discriminator
Discriminator = descriminator(HR)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

Discriminator.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=['accuracy'])
Discriminator.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 96, 96, 3)]       0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 96, 96, 64)        1792
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 96, 96, 64)        0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 48, 48, 64)        36928
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 48, 48, 64)        256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 48, 48, 64)        0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 48, 48, 128)       73856
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 48, 48, 128)       512
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 48, 48, 128)       0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 24, 24, 128)       147584
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 24, 24, 128)       512
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 24, 24, 128)       0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 24, 24, 256)       295168
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 24, 24, 256)       1024
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 24, 24, 256)       0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 12, 12, 256)       590080
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 12, 12, 256)       1024
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 12, 12, 256)       0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 12, 12, 512)       1180160
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 12, 12, 512)       2048
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 12, 12, 512)       0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 6, 6, 512)         2359808
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 6, 6, 512)         2048
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              18875392
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 23,569,217
# Trainable params: 23,565,505
# Non-trainable params: 3,712
# _________________________________________________________________

# %%
#Linking the models
GAN = Link_GAN(Generator, Discriminator, vgg19, LR, HR)
GAN.compile(loss=["binary_crossentropy", "mse"], loss_weights=[1e-3, 1], optimizer=optimizer)
GAN.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 24, 24, 3)]  0
# __________________________________________________________________________________________________
# model_1 (Functional)            (None, 96, 96, 3)    2005571     input_2[0][0]
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 96, 96, 3)]  0
# __________________________________________________________________________________________________
# model_2 (Functional)            (None, 1)            23569217    model_1[0][0]
# __________________________________________________________________________________________________
# model (Functional)              (None, 6, 6, 512)    20024384    model_1[0][0]
# ==================================================================================================
# Total params: 45,599,172
# Trainable params: 2,001,475
# Non-trainable params: 43,597,697
# __________________________________________________________________________________________________

# %% [markdown]
# #epochs = 100
# #Generator = load_model('gen_e_55.h5', compile=False)
# #Discriminator = load_model('dis_e_55.h5', compile=False)
#
# Discriminator.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=['accuracy'])
#
# epochs = 30
# BATCHSIZE=16
# NUM_SKIPPED_BS= 0
# #Enumerate training over epochs
# for e in range(epochs):
#
#     fake_label = np.zeros((BATCHSIZE, 1)) # Assign a label of 0 to all fake (generated images)
#     real_label = np.ones((BATCHSIZE,1)) # Assign a label of 1 to all real images.
#
#     #Create empty lists to populate gen and disc losses.
#     g_losses = []
#     d_losses = []
#
#     #Enumerate training over batches.
#     dataloader = get_batch(batchSize=BATCHSIZE)
#
#     for b in tqdm(range(len(ImgDataset)//BATCHSIZE)):
#
#         try:
#             lr_imgs,hr_imgs = next(dataloader)
#         except:
#             NUM_SKIPPED_BS+=1
#             continue
#
#         fake_imgs = Generator.predict_on_batch(lr_imgs) #Fake images
#
#         #First, train the discriminator on fake and real HR images.
#         Discriminator.trainable = True
#         d_loss_gen = Discriminator.train_on_batch(fake_imgs, fake_label)
#         d_loss_real = Discriminator.train_on_batch(hr_imgs, real_label)
#
#         #Now, train the generator by fixing discriminator as non-trainable
#         Discriminator.trainable = False
#
#         #Average the discriminator loss, just for reporting purposes.
#         d_loss = 0.5 * np.add(d_loss_gen, d_loss_real)
#
#         #Extract VGG features, to be used towards calculating loss
#         image_features = vgg19.predict(hr_imgs)
#
#         #Train the generator via GAN.
#         #Remember that we have 2 losses, adversarial loss and content (VGG) loss
#         g_loss, _, _ = GAN.train_on_batch([lr_imgs, hr_imgs], [real_label, image_features])
#
#         #Save losses to a list so we can average and report.
#         d_losses.append(d_loss)
#         g_losses.append(g_loss)
#
#     #Convert the list of losses to an array to make it easy to average
#     g_losses = np.array(g_losses)
#     d_losses = np.array(d_losses)
#
#     #Calculate the average losses for generator and discriminator
#     g_loss = np.sum(g_losses, axis=0) / len(g_losses)
#     d_loss = np.sum(d_losses, axis=0) / len(d_losses)
#
#     #Report the progress during training.
#     if (e+1) % 5 == 0:
#         print("epoch:", e+1 ,"g_loss:", g_loss, "d_loss:", d_loss)
#
#     if (e+1) % 10 == 0: #Change the frequency for model saving, if needed
#         #Save the generator after every n epochs (Usually 10 epochs)
#         Generator.save("gen_e_"+ str(e+1) +".h5")

# %% [markdown]
# # Visualizing the reults

# %% [markdown]
# ## Loss curves

# %% [markdown]
# plt.subplot(1,2,1)
# plt.plot(g_losses)
# plt.title("the generative loss")
# plt.subplot(1,2,2)
# plt.plot(d_losses)
# plt.title("the Discriminatie loss")

# %% [markdown]
# ## Images after passing to the gen model

# %%
# Discriminator.compile(loss="binary_crossentropy", optimizer=optimizer, metrics=['accuracy'])

# epochs = 10
# BATCHSIZE=16
# NUM_SKIPPED_BS= 0  #Enumerate training over epochs for e in range(epochs):

# for e in range(epochs):  # Define 'e' as the epoch number

#     fake_label = np.zeros((BATCHSIZE, 1)) # Assign a label of 0 to all fake (generated images)
#     real_label = np.ones((BATCHSIZE,1))   # Assign a label of 1 to all real images.
    
#     #Create empty lists to populate gen and disc losses. 
#     g_losses = []
#     d_losses = []
    
#     #Enumerate training over batches. 
#     dataloader = get_batch(batchSize=BATCHSIZE)
    
#     for b in tqdm(range(len(ImgDataset)//BATCHSIZE)):
        
#         try:
#             lr_imgs,hr_imgs = next(dataloader)
#         except: 
#             NUM_SKIPPED_BS+=1 
#             continue
        
#         fake_imgs = Generator.predict_on_batch(lr_imgs) #Fake images
        
#         #First, train the discriminator on fake and real HR images. 
#         Discriminator.trainable = True
#         d_loss_gen = Discriminator.train_on_batch(fake_imgs, fake_label)
#         d_loss_real = Discriminator.train_on_batch(hr_imgs, real_label)
        
#         #Now, train the generator by fixing discriminator as non-trainable
#         Discriminator.trainable = False
        
#         #Average the discriminator loss, just for reporting purposes. 
#         d_loss = 0.5 * np.add(d_loss_gen, d_loss_real) 
        
#         #Extract VGG features, to be used towards calculating loss
#         image_features = vgg19.predict(hr_imgs)
     
#         #Train the generator via GAN. 
#         #Remember that we have 2 losses, adversarial loss and content (VGG) loss
#         g_loss, _, _ = GAN.train_on_batch([lr_imgs, hr_imgs], [real_label, image_features])
        
#         #Save losses to a list so we can average and report. 
#         d_losses.append(d_loss)
#         g_losses.append(g_loss)
        
#     #Convert the list of losses to an array to make it easy to average    
#     g_losses = np.array(g_losses)
#     d_losses = np.array(d_losses)
    
#     #Calculate the average losses for generator and discriminator
#     g_loss = np.sum(g_losses, axis=0) / len(g_losses)
#     d_loss = np.sum(d_losses, axis=0) / len(d_losses)
    
#     #Report the progress during training. 
#     # if (e+1) % 5 == 0:
#     print("epoch:", e+1 ,"g_loss:", g_loss, "d_loss:", d_loss)
    
#     if (e+1) % 10 == 0: #Change the frequency for model saving, if needed
#         #Save the generator after every n epochs (Usually 10 epochs)
#         Generator.save("gen_e_"+ str(e+1) +".h5")
    

Generator = load_model('/kaggle/working/gen_e_10.h5', compile=False)

# %%
import random

plt.figure(figsize=(15,15)) 
for i in range(5):
    idx= random.randint(0,len(ImgDataset))
    lr,hr = prepare_Image_tf(ImgDataset[idx])
    # plotting the LR img
    plt.subplot(5,4,i*4+1)
    plt.imshow(lr)
    if i==0:
        plt.title("Low Resolution")

    # plotting the orignal img 
    plt.subplot(5,4,i*4+2)
    plt.imshow((hr+1)/2 )
    if i==0:
        plt.title("OG img")
    
    
    #now plotting the recovered image
    fake_imgs = Generator.predict(tf.expand_dims(lr,axis=0))
    plt.subplot(5,4,i*4+3)    
    plt.imshow((fake_imgs[0]+1)/2)
    if i==0:
        plt.title("Generated Img")
    
    # plotting the normal cubic interpolation 
    # hr1= cv2.resize(lr.numpy(),dsize=(96,96),interpolation=cv2.INTER_CUBIC)
    # hr1= cv2.normalize(np.array(hr1), 0, 1,dtype=cv2.CV_32F,norm_type=cv2.NORM_MINMAX)
    
    # plt.subplot(5,4,i*4+4)
    # plt.imshow(hr1) 
    # if i==0:
    #     plt.title("Bi-Cubic Interp")

# %%
plt.subplot(1,2,1) 
plt.plot(g_losses) 
plt.title("the generative loss")
plt.subplot(1,2,2)
plt.plot(d_losses)
plt.title("the Discriminative loss")
# Out:
# Text(0.5, 1.0, 'the Discriminatie loss')

# %%
# !pip freeze > kaggle_environment.txt
